# %%
import os, sys

try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    if not os.path.exists("Scaling-book"):
        # !git clone https://github.com/arjuns238/Scaling-book.git
    # %cd Scaling-book/Addition_Transformer
    # !pip install -q flax optax
# Out:
# Cloning into 'Scaling-book'...
# remote: Enumerating objects: 62, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 62 (delta 31), reused 41 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (62/62), 168.78 KiB | 2.68 MiB/s, done.
# Resolving deltas: 100% (31/31), done.
# /content/Scaling-book/Addition_Transformer/Scaling-book/Addition_Transformer/Scaling-book/Addition_Transformer

# %%
# # chose configs - ~10M params
# from model import *
# from data import build_dataset, generate_split, Dataloader
# import numpy as np
from config import Config
cfg = Config(
    d_model=384,
    ffw_multiplier=8/3,
    num_layers=6,
    query_heads=6,
    kv_heads=6,
    key_dim=64,
    vocab_size=16,
    batch_size = 512,
    dtype=jnp.bfloat16,
    lr = 1e-3,
    num_epochs = 15,
)

# %%
from utils import *
# Your size ladder (recompute real N per config with count_params).
SIZE_LADDER = [(64, 2), (96, 3), (128, 3), (192, 4), (256, 5), (384, 6)]

# Precompute (d_model, num_layers, N) once so we can pick sizes by N.
def size_table(base):
    table = []
    for dm, nl in SIZE_LADDER:
        w = Weights.init(make_cfg(base, dm, nl), jax.random.key(0))
        table.append((dm, nl, count_params(w)))
    return table  # list of (d_model, num_layers, N)

# %%
size_table(cfg)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7511/527066591.py in <cell line: 0>()
# ----> 1 size_table(cfg)
#
# /tmp/ipykernel_7511/2644496185.py in size_table(base)
#       8     for dm, nl in SIZE_LADDER:
#       9         w = Weights.init(make_cfg(base, dm, nl), jax.random.key(0))
# ---> 10         table.append((dm, nl, count_params(w)))
#      11     return table  # list of (d_model, num_layers, N)
#
# /content/Scaling-book/Addition_Transformer/Scaling-book/Addition_Transformer/Scaling-book/Addition_Transformer/utils.py in count_params(weights)
#      16
#      17 def count_params(weights):
# ---> 18     return sum(x.size for x in jax.tree_util.leaves(weights))
#      19
#      20 def make_cfg(base, d_model, num_layers):
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/deprecations.py in getattr(name)
#      55       warnings.warn(message, DeprecationWarning, stacklevel=2)
#      56       return fn
# ---> 57     raise AttributeError(f"module {module!r} has no attribute {name!r}")
#      58
#      59   return getattr
#
# AttributeError: module 'jax.tree_util' has no attribute 'leaves'
